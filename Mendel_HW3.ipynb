# %%
import pandas as pd
import networkx as nx
from tqdm import tqdm
import itertools
from sys import maxsize
from node2vec import Node2Vec
from node2vec.edges import HadamardEmbedder

# %%
data = pd.read_csv("data2.csv")

# %%
data = data[:].loc[data.Source == 'Climate Dynamics']

# %% [markdown]
# # 1. Initiallize your classification set as follows

# %%
def graph_assemble(d, year_begin, year_end):
    data = d.copy()
    data["Authors"] = data["Authors"].apply(lambda x: x.split("; "))
    data["Authors"] = data["Authors"].apply(lambda x: x[:200] if len(x) > 200 else x)

    d1 = data["Authors"].loc[(data.Year >= year_begin) & (data.Year <= year_end - 4)].values
    d2 = data["Authors"].loc[(data.Year >= year_end - 4) & (data.Year <= year_end)].values

    coauthors1, coauthors2 = {}, {}

    for art in tqdm(d1):
        for x in itertools.permutations(art, r=2):
            coauthors1[x] = coauthors1.get(x, 0) + 1

    for art in tqdm(d2):
        for x in itertools.permutations(art, r=2):
            coauthors2[x] = coauthors2.get(x, 0) + 1

    G1, G2 = nx.Graph(), nx.Graph()
    G1.add_edges_from([key + tuple([{'weight': value}]) for key,value in coauthors1.items()])
    G2.add_edges_from([key + tuple([{'weight': value}]) for key,value in coauthors2.items()])
    
    return G1, G2

# %%
def make_sample(G1, G2, year):
    node2vec = Node2Vec(G1)
    model = node2vec.fit(window=10, min_count=1, batch_words=4)
    edges_embs = HadamardEmbedder(keyed_vectors=model.wv)
    comp_G1 = nx.complement(G1)
    for v1, v2 in comp_G1.edges():
        if (v1 in G2.nodes() and v2 in G2.nodes()):
            nb = len(list(nx.common_neighbors(G1, v1, v2)))
            jc = list(nx.jaccard_coefficient(G1, [(v1, v2)]))[0][2]
            if ((v1, v2) in G2.edges()):
                A.append({'target':1,
                          'Auth1':v1,
                          'Auth2':v2,
                          'shortest_path_length':1,
                          'common_neighbors':nb,
                          'jaccard_coefficient':jc,
                          'year_of_addition':year,
                          'density':nx.density(G1),
                          'node2vek1':edges_embs[(v1, v2)][0],
                          'node2vek2':edges_embs[(v1, v2)][1],
                          'node2vek3':edges_embs[(v1, v2)][2]})
            else: 
                if (nx.has_path(G1, v1, v2)):
                    length = nx.shortest_path_length(G1, v1, v2)
                else:
                    length =  -1
                A.append({'target':0,
                          'Auth1':v1,
                          'Auth2':v2,
                          'shortest_path_length':length,
                          'common_neighbors':nb,
                          'jaccard_coefficient':jc,
                          'year_of_addition':year,
                          'density':nx.density(G1),
                          'node2vek1':edges_embs[(v1, v2)][0],
                          'node2vek2':edges_embs[(v1, v2)][1],
                          'node2vek3':edges_embs[(v1, v2)][2]})

# %% [markdown]
# # 2. Construct feature space

# %%
A = []
for year in sorted(data['Year'].unique()):
    if (year == 2010):
        break
    G1, G2 = graph_assemble(data, year, year + 8)
    make_sample(G1, G2, year + 8)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
#
# 100%|██████████| 4/4 [00:00<00:00, 2328.23it/s]
#
#   0%|          | 0/19 [00:00<?, ?it/s]
#
# 100%|██████████| 19/19 [00:00<00:00, 10154.41it/s]
#
# Computing transition probabilities:   0%|          | 0/6 [00:00<?, ?it/s]
#
# Computing transition probabilities: 100%|██████████| 6/6 [00:00<00:00, 3223.91it/s]
#
# Generating walks (CPU: 1):   0%|          | 0/10 [00:00<?, ?it/s]
#
# Generating walks (CPU: 1):  30%|███       | 3/10 [00:00<00:00, 27.10it/s]
#
# Generating walks (CPU: 1):  60%|██████    | 6/10 [00:00<00:00, 27.60it/s]
#
# Generating walks (CPU: 1): 100%|██████████| 10/10 [00:00<00:00, 29.75it/s]
#
#
#
#   0%|          | 0/17 [00:00<?, ?it/s]
#
# 100%|██████████| 17/17 [00:00<00:00, 6784.32it/s]
#
#   0%|          | 0/37 [00:00<?, ?it/s]
#
# 100%|██████████| 37/37 [00:00<00:00, 14315.03it/s]
#
# Computing transition probabilities:   0%|          | 0/58 [00:00<?, ?it/s]
#
# Computing transition probabilities: 100%|██████████| 58/58 [00:00<00:00, 615.11it/s]
#
# Generating walks (CPU: 1):   0%|          | 0/10 [00:00<?, ?it/s]
#
# Generating walks (CPU: 1):  20%|██        | 2/10 [00:00<00:00,  8.28it/s]
#
# Generating walks (CPU: 1):  30%|███       | 3/10 [00:00<00:01,  6.07it/s]
#
# Generating walks (CPU: 1):  40%|████      | 4/10 [00:00<00:01,  4.92it/s]
#
# Generating walks (CPU: 1):  50%|█████     | 5/10 [00:01<00:01,  4.69it/s]
#
# Generating walks (CPU: 1):  60%|██████    | 6/10 [00:01<00:00,  4.29it/s]
#
# Generating walks (CPU: 1):  70%|███████   | 7/10 [00:01<00:00,  4.26it/s]
#
# Generating walks (CPU: 1):  80%|████████  | 8/10 [00:01<00:00,  4.19it/s]
#
# Generating walks (CPU: 1):  90%|█████████ | 9/10 [00:02<00:00,  4.08it/s]
#
# Generating walks (CPU: 1): 100%|██████████| 10/10 [00:02<00:00,  3.98it/s]
#
#
#
#   0%|          | 0/25 [00:00<?, ?it/s]
#
# 100%|██████████| 25/25 [00:00<00:00, 7534.50it/s]
#
#   0%|          | 0/61 [00:00<?, ?it/s]
#
# 100%|██████████| 61/61 [00:00<00:00, 17889.28it/s]
#
# Computing transition probabilities:   0%|          | 0/100 [00:00<?, ?it/s]
#
# Computing transition probabilities:  80%|████████  | 80/100 [00:00<00:00, 783.46it/s]
#
# Computing transition probabilities: 100%|██████████| 100/100 [00:00<00:00, 540.82it/s]
#
# Generating walks (CPU: 1):   0%|          | 0/10 [00:00<?, ?it/s]
#
# Generating walks (CPU: 1):  20%|██        | 2/10 [00:00<00:01,  4.64it/s]
#
# Generating walks (CPU: 1):  30%|███       | 3/10 [00:00<00:01,  3.75it/s]
#
# Generating walks (CPU: 1):  40%|████      | 4/10 [00:01<00:01,  3.30it/s]
#
# Generating walks (CPU: 1):  50%|█████     | 5/10 [00:01<00:01,  3.01it/s]
#
# Generating walks (CPU: 1):  60%|██████    | 6/10 [00:01<00:01,  2.87it/s]
#
# Generating walks (CPU: 1):  70%|███████   | 7/10 [00:02<00:01,  2.61it/s]
#
# Generating walks (CPU: 1):  80%|████████  | 8/10 [00:02<00:00,  2.55it/s]
#
# Generating walks (CPU: 1):  90%|█████████ | 9/10 [00:03<00:00,  2.49it/s]
#
# Generating walks (CPU: 1): 100%|██████████| 10/10 [00:03<00:00,  2.43it/s]
#
#
#
#   0%|          | 0/32 [00:00<?, ?it/s]
#
# 100%|██████████| 32/32 [00:00<00:00, 9822.73it/s]
#
#   0%|          | 0/74 [00:00<?, ?it/s]
#
# 100%|██████████| 74/74 [00:00<00:00, 18102.09it/s]
#
# Computing transition probabilities:   0%|          | 0/106 [00:00<?, ?it/s]
#
# Computing transition probabilities:  54%|█████▍    | 57/106 [00:00<00:00, 559.95it/s]
#
# Computing transition probabilities: 100%|██████████| 106/106 [00:00<00:00, 733.30it/s]
#
# Generating walks (CPU: 1):   0%|          | 0/10 [00:00<?, ?it/s]
#
# Generating walks (CPU: 1):  20%|██        | 2/10 [00:00<00:01,  4.79it/s]
#
# Generating walks (CPU: 1):  30%|███       | 3/10 [00:00<00:01,  3.73it/s]
#
# Generating walks (CPU: 1):  40%|████      | 4/10 [00:01<00:01,  3.20it/s]
#
# Generating walks (CPU: 1):  50%|█████     | 5/10 [00:01<00:01,  2.93it/s]
#
# Generating walks (CPU: 1):  60%|██████    | 6/10 [00:02<00:01,  2.74it/s]
#
# Generating walks (CPU: 1):  70%|███████   | 7/10 [00:02<00:01,  2.54it/s]
#
# Generating walks (CPU: 1):  80%|████████  | 8/10 [00:02<00:00,  2.42it/s]
#
# Generating walks (CPU: 1):  90%|█████████ | 9/10 [00:03<00:00,  2.38it/s]
#
# Generating walks (CPU: 1): 100%|██████████| 10/10 [00:03<00:00,  2.38it/s]
#
#
#
#   0%|          | 0/37 [00:00<?, ?it/s]
#
# 100%|██████████| 37/37 [00:00<00:00, 11225.26it/s]
#
#   0%|          | 0/86 [00:00<?, ?it/s]
#
# 100%|██████████| 86/86 [00:00<00:00, 12907.40it/s]
#
# Computing transition probabilities:   0%|          | 0/127 [00:00<?, ?it/s]
#
# Computing transition probabilities:  84%|████████▍ | 107/127 [00:00<00:00, 1038.91it/s]
#
# Computing transition probabilities: 100%|██████████| 127/127 [00:00<00:00, 986.05it/s]
#
# Generating walks (CPU: 1):   0%|          | 0/10 [00:00<?, ?it/s]
#
# Generating walks (CPU: 1):  20%|██        | 2/10 [00:00<00:02,  3.96it/s]
#
# Generating walks (CPU: 1):  30%|███       | 3/10 [00:01<00:02,  2.97it/s]
#
# Generating walks (CPU: 1):  40%|████      | 4/10 [00:01<00:02,  2.30it/s]
#
# Generating walks (CPU: 1):  50%|█████     | 5/10 [00:02<00:02,  2.24it/s]
#
# Generating walks (CPU: 1):  60%|██████    | 6/10 [00:02<00:01,  2.18it/s]
#
# Generating walks (CPU: 1):  70%|███████   | 7/10 [00:03<00:01,  2.14it/s]
#
# Generating walks (CPU: 1):  80%|████████  | 8/10 [00:03<00:00,  2.08it/s]
#
# Generating walks (CPU: 1):  90%|█████████ | 9/10 [00:04<00:00,  2.06it/s]
#
# Generating walks (CPU: 1): 100%|██████████| 10/10 [00:04<00:00,  2.06it/s]
#
#
#
#   0%|          | 0/47 [00:00<?, ?it/s]
#
# 100%|██████████| 47/47 [00:00<00:00, 14355.69it/s]
#
#   0%|          | 0/93 [00:00<?, ?it/s]
#
# 100%|██████████| 93/93 [00:00<00:00, 15043.20it/s]
#
# Computing transition probabilities:   0%|          | 0/164 [00:00<?, ?it/s]
#
# Computing transition probabilities:  63%|██████▎   | 103/164 [00:00<00:00, 997.12it/s]
#
# Computing transition probabilities: 100%|██████████| 164/164 [00:00<00:00, 1165.36it/s]
#
# Generating walks (CPU: 1):   0%|          | 0/10 [00:00<?, ?it/s]
#
# Generating walks (CPU: 1):  20%|██        | 2/10 [00:00<00:02,  3.26it/s]
#
# Generating walks (CPU: 1):  30%|███       | 3/10 [00:01<00:02,  2.50it/s]
#
# Generating walks (CPU: 1):  40%|████      | 4/10 [00:01<00:02,  2.15it/s]
#
# Generating walks (CPU: 1):  50%|█████     | 5/10 [00:02<00:02,  1.95it/s]
#
# Generating walks (CPU: 1):  60%|██████    | 6/10 [00:03<00:02,  1.83it/s]
#
# Generating walks (CPU: 1):  70%|███████   | 7/10 [00:03<00:01,  1.76it/s]
#
# Generating walks (CPU: 1):  80%|████████  | 8/10 [00:04<00:01,  1.67it/s]
#
# Generating walks (CPU: 1):  90%|█████████ | 9/10 [00:05<00:00,  1.66it/s]
#
# Generating walks (CPU: 1): 100%|██████████| 10/10 [00:05<00:00,  1.64it/s]
#
#
#
#   0%|          | 0/61 [00:00<?, ?it/s]
#
# 100%|██████████| 61/61 [00:00<00:00, 15616.00it/s]
#
#   0%|          | 0/109 [00:00<?, ?it/s]
#
# 100%|██████████| 109/109 [00:00<00:00, 19148.86it/s]
#
# Computing transition probabilities:   0%|          | 0/211 [00:00<?, ?it/s]
#
# Computing transition probabilities:  60%|██████    | 127/211 [00:00<00:00, 1205.88it/s]
#
# Computing transition probabilities: 100%|██████████| 211/211 [00:00<00:00, 1270.59it/s]
#
# Generating walks (CPU: 1):   0%|          | 0/10 [00:00<?, ?it/s]
#
# Generating walks (CPU: 1):  20%|██        | 2/10 [00:00<00:03,  2.48it/s]
#
# Generating walks (CPU: 1):  30%|███       | 3/10 [00:01<00:03,  1.95it/s]
#
# Generating walks (CPU: 1):  40%|████      | 4/10 [00:02<00:03,  1.67it/s]
#
# Generating walks (CPU: 1):  50%|█████     | 5/10 [00:03<00:03,  1.51it/s]
#
# Generating walks (CPU: 1):  60%|██████    | 6/10 [00:03<00:02,  1.44it/s]
#
# Generating walks (CPU: 1):  70%|███████   | 7/10 [00:04<00:02,  1.39it/s]
#
# Generating walks (CPU: 1):  80%|████████  | 8/10 [00:05<00:01,  1.35it/s]
# Generating walks (CPU: 1):  90%|█████████ | 9/10 [00:06<00:00,  1.33it/s]
#
# Generating walks (CPU: 1): 100%|██████████| 10/10 [00:07<00:00,  1.30it/s]
#
#
#
#   0%|          | 0/74 [00:00<?, ?it/s]
#
# 100%|██████████| 74/74 [00:00<00:00, 16818.12it/s]
#
#   0%|          | 0/114 [00:00<?, ?it/s]
#
# 100%|██████████| 114/114 [00:00<00:00, 17364.56it/s]
#
# Computing transition probabilities:   0%|          | 0/248 [00:00<?, ?it/s]
# Computing transition probabilities:  23%|██▎       | 58/248 [00:00<00:00, 556.86it/s]
# Computing transition probabilities:  30%|███       | 75/248 [00:00<00:00, 318.27it/s]
# Computing transition probabilities:  89%|████████▉ | 221/248 [00:00<00:00, 657.38it/s]
# Computing transition probabilities: 100%|██████████| 248/248 [00:00<00:00, 709.75it/s]
# Generating walks (CPU: 1):   0%|          | 0/10 [00:00<?, ?it/s]
# Generating walks (CPU: 1):  20%|██        | 2/10 [00:00<00:03,  2.22it/s]
# Generating walks (CPU: 1):  30%|███       | 3/10 [00:01<00:04,  1.71it/s]
# Generating walks (CPU: 1):  40%|████      | 4/10 [00:02<00:04,  1.46it/s]
# Exception in thread Thread-1682:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python/3.6.5_1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/usr/local/lib/python3.6/site-packages/tqdm/_monitor.py", line 63, in run
#     for instance in self.tqdm_cls._instances:
#   File "/usr/local/Cellar/python/3.6.5_1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/_weakrefset.py", line 60, in __iter__
#     for itemref in self.data:
# RuntimeError: Set changed size during iteration
#
# Generating walks (CPU: 1): 100%|██████████| 10/10 [00:08<00:00,  1.12it/s]
# 100%|██████████| 86/86 [00:00<00:00, 46687.83it/s]
# 100%|██████████| 135/135 [00:00<00:00, 34723.19it/s]
# Computing transition probabilities: 100%|██████████| 306/306 [00:00<00:00, 517.64it/s]
# Generating walks (CPU: 1): 100%|██████████| 10/10 [00:10<00:00,  1.09s/it]
# 100%|██████████| 93/93 [00:00<00:00, 38510.25it/s]
# 100%|██████████| 149/149 [00:00<00:00, 50891.80it/s]
# Computing transition probabilities: 100%|██████████| 340/340 [00:00<00:00, 540.25it/s]
# Generating walks (CPU: 1): 100%|██████████| 10/10 [00:11<00:00,  1.23s/it]
# 100%|██████████| 109/109 [00:00<00:00, 45494.99it/s]
# 100%|██████████| 173/173 [00:00<00:00, 42339.51it/s]
# Computing transition probabilities: 100%|██████████| 366/366 [00:00<00:00, 576.56it/s]
# Generating walks (CPU: 1): 100%|██████████| 10/10 [00:13<00:00,  1.47s/it]
# 100%|██████████| 114/114 [00:00<00:00, 20595.74it/s]
# 100%|██████████| 177/177 [00:00<00:00, 40719.16it/s]
# Computing transition probabilities: 100%|██████████| 373/373 [00:00<00:00, 458.98it/s]
# Generating walks (CPU: 1): 100%|██████████| 10/10 [00:13<00:00,  1.53s/it]
# 100%|██████████| 135/135 [00:00<00:00, 32243.67it/s]
# 100%|██████████| 188/188 [00:00<00:00, 53243.02it/s]
# Computing transition probabilities: 100%|██████████| 456/456 [00:00<00:00, 595.54it/s]
# Generating walks (CPU: 1): 100%|██████████| 10/10 [00:15<00:00,  1.62s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-549-614af51c04c8> in <module>()
#       4         break
#       5     G1, G2 = graph_assemble(data, year, year + 8)
# ----> 6     make_sample(G1, G2, year + 8)
#
# <ipython-input-542-6eae827bcae6> in make_sample(G1, G2, year)
#      32                           'jaccard_coefficient':jc,
#      33                           'year_of_addition':year,
# ---> 34                           'density':nx.density(G1),
#      35                           'node2vek1':edges_embs[(v1, v2)][0],
#      36                           'node2vek2':edges_embs[(v1, v2)][1],
#
# /usr/local/lib/python3.6/site-packages/networkx/classes/function.py in density(G)
#     101     """
#     102     n = number_of_nodes(G)
# --> 103     m = number_of_edges(G)
#     104     if m == 0 or n <= 1:
#     105         return 0
#
# /usr/local/lib/python3.6/site-packages/networkx/classes/function.py in number_of_edges(G)
#      72 def number_of_edges(G):
#      73     """Return the number of edges in the graph. """
# ---> 74     return G.number_of_edges()
#      75
#      76
#
# /usr/local/lib/python3.6/site-packages/networkx/classes/graph.py in number_of_edges(self, u, v)
#    1837         """
#    1838         if u is None:
# -> 1839             return int(self.size())
#    1840         if v in self._adj[u]:
#    1841             return 1
#
# /usr/local/lib/python3.6/site-packages/networkx/classes/graph.py in size(self, weight)
#    1783         6.0
#    1784         """
# -> 1785         s = sum(d for v, d in self.degree(weight=weight))
#    1786         # If `weight` is None, the sum of the degrees is guaranteed to be
#    1787         # even, so we can perform integer division and hence return an
#
# /usr/local/lib/python3.6/site-packages/networkx/classes/graph.py in <genexpr>(.0)
#    1783         6.0
#    1784         """
# -> 1785         s = sum(d for v, d in self.degree(weight=weight))
#    1786         # If `weight` is None, the sum of the degrees is guaranteed to be
#    1787         # even, so we can perform integer division and hence return an
#
# /usr/local/lib/python3.6/site-packages/networkx/classes/reportviews.py in __iter__(self)
#     445             for n in self._nodes:
#     446                 nbrs = self._succ[n]
# --> 447                 yield (n, len(nbrs) + (n in nbrs))
#     448         else:
#     449             for n in self._nodes:
#
# KeyboardInterrupt:

# %%
df = pd.DataFrame(A)

# %% [markdown]
# # 3. Choose at least  3 classification algorithms

# %%
A = []
G1, G2 = graph_assemble(data, 2011, 2019)
node2vec = Node2Vec(G1)
model = node2vec.fit(window=10, min_count=1, batch_words=4)
edges_embs = HadamardEmbedder(keyed_vectors=model.wv)
comp_G1 = nx.complement(G1)
for v1, v2 in comp_G1.edges():
    if (v1 in G2.nodes() and v2 in G2.nodes()):
            nb = len(list(nx.common_neighbors(G1, v1, v2)))
            jc = list(nx.jaccard_coefficient(G1, [(v1, v2)]))[0][2]
            if ((v1, v2) in G2.edges()):
                A.append({'target':1,
                          'shortest_path_length':1,
                          'common_neighbors':nb,
                          'jaccard_coefficient':jc,
                          'year_of_addition':year,
                          'density':nx.density(G1),
                          'node2vek1':edges_embs[(v1, v2)][0],
                          'node2vek2':edges_embs[(v1, v2)][1],
                          'node2vek3':edges_embs[(v1, v2)][2]})
            else:
                if (nx.has_path(G1, v1, v2)):
                    length = nx.shortest_path_length(G1, v1, v2)
                else:
                    length =  -1
                A.append({'target':0,
                          'shortest_path_length':length,
                          'common_neighbors':nb,
                          'jaccard_coefficient':jc,
                          'year_of_addition':year,
                          'density':nx.density(G1),
                          'node2vek1':edges_embs[(v1, v2)][0],
                          'node2vek2':edges_embs[(v1, v2)][1],
                          'node2vek3':edges_embs[(v1, v2)][2]})
dfTest = pd.DataFrame(A)
yTest = dfTest.target
XTest = dfTest.drop(['target'], axis = 1)
yTrain = df.target
XTrain = df.drop(['target', 'Auth1', 'Auth2'], axis = 1)
# Out:
#   0%|          | 0/123 [00:00<?, ?it/s]
#
# 100%|██████████| 123/123 [00:00<00:00, 7874.52it/s]
#
#   0%|          | 0/24 [00:00<?, ?it/s]
#
# 100%|██████████| 24/24 [00:00<00:00, 2842.87it/s]
#
# Computing transition probabilities:   0%|          | 0/540 [00:00<?, ?it/s]
#
# Computing transition probabilities:   9%|▉         | 48/540 [00:00<00:01, 474.32it/s]
#
# Computing transition probabilities:  24%|██▍       | 129/540 [00:00<00:00, 635.52it/s]
#
# Computing transition probabilities:  31%|███       | 166/540 [00:00<00:00, 537.42it/s]
#
# Computing transition probabilities:  45%|████▍     | 241/540 [00:00<00:00, 586.03it/s]
#
# Computing transition probabilities:  53%|█████▎    | 288/540 [00:00<00:00, 558.82it/s]
#
# Computing transition probabilities:  62%|██████▏   | 334/540 [00:01<00:00, 289.06it/s]
#
# Computing transition probabilities:  68%|██████▊   | 369/540 [00:02<00:00, 173.83it/s]
#
# Computing transition probabilities:  73%|███████▎  | 394/540 [00:02<00:00, 172.12it/s]
#
# Computing transition probabilities:  80%|████████  | 433/540 [00:02<00:00, 181.18it/s]
#
# Computing transition probabilities: 100%|██████████| 540/540 [00:02<00:00, 219.06it/s]
#
# Generating walks (CPU: 1):   0%|          | 0/10 [00:00<?, ?it/s]
#
# Generating walks (CPU: 1):  20%|██        | 2/10 [00:02<00:08,  1.05s/it]
#
# Generating walks (CPU: 1):  30%|███       | 3/10 [00:04<00:09,  1.33s/it]
#
# Generating walks (CPU: 1):  40%|████      | 4/10 [00:06<00:09,  1.53s/it]
#
# Generating walks (CPU: 1):  50%|█████     | 5/10 [00:08<00:08,  1.66s/it]
#
# Generating walks (CPU: 1):  60%|██████    | 6/10 [00:10<00:07,  1.77s/it]
#
# Generating walks (CPU: 1):  70%|███████   | 7/10 [00:12<00:05,  1.84s/it]
#
# Generating walks (CPU: 1):  80%|████████  | 8/10 [00:14<00:04,  2.00s/it]
#
# Generating walks (CPU: 1):  90%|█████████ | 9/10 [00:16<00:02,  2.01s/it]
#
# Generating walks (CPU: 1): 100%|██████████| 10/10 [00:18<00:00,  2.01s/it]

# %%
from sklearn.svm import SVC
from sklearn import model_selection

# %%
clasif = SVC() #SVM
clasif.fit(XTrain, yTrain)

ans1 = clasif.predict(XTest)

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, mean_squared_error, roc_auc_score
print ('SVM recall: ', recall_score(yTest, ans1))
print ('SVM precision: ', precision_score(yTest, ans1))
print ('SVM accuracy: ', accuracy_score(yTest, ans1))
print ('SVM f1_score: ', f1_score(yTest, ans1))
print ('SVM mean_squared_error: ', mean_squared_error(yTest, ans1))
print ('AUC-ROC', roc_auc_score(yTest, ans1))
print ("GINI = {}".format(round(2 * roc_auc_score(yTest, ans1) - 1, 2)))
# Out:
# SVM recall:  1.0
# SVM precision:  1.0
# SVM accuracy:  1.0
# SVM f1_score:  1.0
# SVM mean_squared_error:  0.0
# AUC-ROC 1.0
# GINI = 1.0

# %%
from sklearn.neighbors import KNeighborsClassifier

clasif2 = KNeighborsClassifier(n_neighbors=3) #k-NN
clasif2.fit(XTrain, yTrain)

ans2 = clasif2.predict(XTest)

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, mean_squared_error
print ('k-NN recall: ', recall_score(yTest, ans2))
print ('k-NN precision: ', precision_score(yTest, ans2))
print ('k-NN accuracy: ', accuracy_score(yTest, ans2))
print ('k-NN f1_score: ', f1_score(yTest, ans2))
print ('k-NN mean_squared_error: ', mean_squared_error(yTest, ans2))
print ('AUC-ROC', roc_auc_score(yTest, ans2))
print ("GINI = {}".format(round(2 * roc_auc_score(yTest, ans2) - 1, 2)))
# Out:
# k-NN recall:  1.0
# k-NN precision:  1.0
# k-NN accuracy:  1.0
# k-NN f1_score:  1.0
# k-NN mean_squared_error:  0.0
# AUC-ROC 1.0
# GINI = 1.0

# %%
from sklearn.tree import DecisionTreeClassifier

clasif3 = DecisionTreeClassifier() #Decision Tree
clasif3.fit(XTrain, yTrain)

ans3 = clasif3.predict(XTest)

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, mean_squared_error
print ('Decision Tree recall: ', recall_score(yTest, ans3))
print ('Decision Tree precision: ', precision_score(yTest, ans3))
print ('Decision Tree accuracy: ', accuracy_score(yTest, ans3))
print ('Decision Tree f1_score: ', f1_score(yTest, ans3))
print ('Decision Tree mean_squared_error: ', mean_squared_error(yTest, ans3))
print ('AUC-ROC', roc_auc_score(yTest, ans3))
print ("GINI = {}".format(round(2 * roc_auc_score(yTest, ans3) - 1, 2)))
# Out:
# Decision Tree recall:  1.0
# Decision Tree precision:  1.0
# Decision Tree accuracy:  1.0
# Decision Tree f1_score:  1.0
# Decision Tree mean_squared_error:  0.0
# AUC-ROC 1.0
# GINI = 1.0

# %%
from sklearn import linear_model
clasif4 = linear_model.LogisticRegression(solver = 'lbfgs')
clasif4.fit(XTrain, yTrain)

ans4 = clasif4.predict(XTest)

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, mean_squared_error
print ('Logistic Regression recall: ', recall_score(yTest, ans4))
print ('Logistic Regression precision: ', precision_score(yTest, ans4))
print ('Logistic Regression accuracy: ', accuracy_score(yTest, ans4))
print ('Logistic Regression f1_score: ', f1_score(yTest, ans4))
print ('Logistic Regression mean_squared_error: ', mean_squared_error(yTest, ans4))
print ('AUC-ROC', roc_auc_score(yTest, ans4))
print ("GINI = {}".format(round(2 * roc_auc_score(yTest, ans4) - 1, 2)))
# Out:
# Logistic Regression recall:  0.0
# Logistic Regression precision:  0.0
# Logistic Regression accuracy:  0.9976019184652278
# Logistic Regression f1_score:  0.0
# Logistic Regression mean_squared_error:  0.002398081534772182
# AUC-ROC 0.5
# GINI = 0.0
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
